# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import sklearn
from sklearn.cluster import DBSCAN

# %%
df=pd.read_excel("output.xlsx")

# %%
df.head()
# Out:
#    InvoiceNo  StockCode  UnitPrice  Quantity  \
# 0     536365   0.169726       7.65         2
# 1     536365   0.156121       4.25         6
# 2     536366   0.168142       1.85         6
# 3     536366   0.168129       1.85         6
# 4     536367   0.169633       2.10         6
#
#                                lower                        Description  \
# 0       set 7 babushka nesting boxes       SET 7 BABUSHKA NESTING BOXES
# 1  glass star frosted t-light holder  GLASS STAR FROSTED T-LIGHT HOLDER
# 2             hand warmer union jack             HAND WARMER UNION JACK
# 3          hand warmer red polka dot          HAND WARMER RED POLKA DOT
# 4         poppy's playhouse bedroom          POPPY'S PLAYHOUSE BEDROOM
#
#           InvoiceDate  CustomerID         Country
# 0 2010-12-01 08:26:00    1.000000  United Kingdom
# 1 2010-12-01 08:26:00    1.000000  United Kingdom
# 2 2010-12-01 08:28:00    1.000000  United Kingdom
# 3 2010-12-01 08:28:00    1.000000  United Kingdom
# ...

# %%
data=df.iloc[:,1:4]

# %%
data
# Out:
#     StockCode  UnitPrice  Quantity
# 0    0.169726       7.65         2
# 1    0.156121       4.25         6
# 2    0.168142       1.85         6
# 3    0.168129       1.85         6
# 4    0.169633       2.10         6
# 5    0.169673       2.10         6
# 6    0.169686       3.75         8
# 7    0.163842       1.65         6
# 8    0.168009       4.95         3
# 9    0.167996       9.95         2
# 10   0.156441       5.95         3
# 11   0.156454       5.95         3
# 12   0.156747       7.95         4
# 13   0.172495       4.25         6
# 14   0.171869       4.95         3
# 15   0.171856       4.95         3
# 16   0.171883       4.95         3
# 17   0.156468       5.95         3
# 18   0.169407       3.75        24
# 19   0.169393       3.75        24
# 20   0.169380       3.75        12
# 21   0.156042       0.85        12
# 22   0.158158       0.65        24
# 23   0.000000       0.85        48
# 24   0.156933       1.25        24
# 25   0.146870       2.95        18
# ...

# %%
# %%time
model=DBSCAN(eps=0.8).fit(data)
# Out:
# Wall time: 1.99 ms

# %%
print(model)
# Out:
# DBSCAN(algorithm='auto', eps=0.8, leaf_size=30, metric='euclidean',
#     metric_params=None, min_samples=5, n_jobs=None, p=None)

# %%
outliers_df=pd.DataFrame(data)
from collections import Counter
print (Counter(model.labels_))
# Out:
# Counter({-1: 37, 0: 7, 1: 6})

# %%
print(outliers_df[model.labels_==0])
# Out:
#     StockCode  UnitPrice  Quantity
# 2    0.168142       1.85         6
# 3    0.168129       1.85         6
# 4    0.169633       2.10         6
# 5    0.169673       2.10         6
# 7    0.163842       1.65         6
# 39   0.168129       1.85         6
# 40   0.168142       1.85         6

# %%
outliers_df[model.labels_==0].to_excel("cluster1.xlsx")

# %%
outliers_df[model.labels_==-1].to_excel("cluster2.xlsx")

# %%
outliers_df[model.labels_==1].to_excel("cluster3.xlsx")
